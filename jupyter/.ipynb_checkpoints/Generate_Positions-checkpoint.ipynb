# %% [markdown]
# # Generate positions

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
0.108 * 2048
# Out:
# 221.184

# %%
#center = [-819.40,-739.05] # center you picked
#new center
center = [-825.28,-386.64] 
dim_x, dim_y = 10, 10 # x, y dimension of square we want to image
size = int(2048 * 0.108 * 0.95) # each field of view is 2048*0.108 um in x and y
print('size:', size)
frame_dimension = size; # need based selection

print(center, dim_x, dim_y)

# indices of positions
pos_indices = np.indices([dim_x,dim_y]) - np.array([float(dim_x-1)/2,float(dim_y-1)/2])[:,np.newaxis,np.newaxis]
# calculate positions
positions = pos_indices * np.array([frame_dimension,frame_dimension])[:,np.newaxis,np.newaxis] + np.array(center)[:,np.newaxis,np.newaxis]
# sort position
sorted_positions = np.zeros([dim_x*dim_y, 2])
for i in range(dim_x):
    if not i%2:
        sorted_positions[i*dim_y:(i+1)*dim_y,:] = positions[:,i].transpose()
    else:
        sorted_positions[i*dim_y:(i+1)*dim_y,:] = np.fliplr(positions[:,i]).transpose()
sorted_positions = np.round(sorted_positions, 1)
# Out:
# size: 210
# [-825.28, -386.64] 10 10

# %%
plt.figure(figsize=(dim_x, dim_y))
plt.plot(sorted_positions[:,0],sorted_positions[:,1],'o-')
plt.show()

# %%
# write into a file
data_folder = r'D:\Pu\20211201-P_brain_CTP11-1000_M1_DNA_RNA-hybrid'
fl = os.path.join(data_folder, 'positions_4.txt')

f = open(fl,'w')
for position in sorted_positions:
    f.write(str(position[0])+", "+str(position[1])+"\n")
f.close()

# %%
for position in sorted_positions:
    print(str(position[0])+", "+str(position[1]))
# Out:
# -945.0, -945.0
# -945.0, -735.0
# -945.0, -525.0
# -945.0, -315.0
# -945.0, -105.0
# -945.0, 105.0
# -945.0, 315.0
# -945.0, 525.0
# -945.0, 735.0
# -945.0, 945.0
# -735.0, 945.0
# -735.0, 735.0
# -735.0, 525.0
# -735.0, 315.0
# -735.0, 105.0
# -735.0, -105.0
# -735.0, -315.0
# -735.0, -525.0
# -735.0, -735.0
# -735.0, -945.0
# -525.0, -945.0
# -525.0, -735.0
# -525.0, -525.0
# -525.0, -315.0
# -525.0, -105.0
# -525.0, 105.0
# -525.0, 315.0
# -525.0, 525.0
# -525.0, 735.0
# -525.0, 945.0
# -315.0, 945.0
# -315.0, 735.0
# -315.0, 525.0
# -315.0, 315.0
# -315.0, 105.0
# -315.0, -105.0
# -315.0, -315.0
# -315.0, -525.0
# -315.0, -735.0
# -315.0, -945.0
# -105.0, -945.0
# -105.0, -735.0
# -105.0, -525.0
# -105.0, -315.0
# -105.0, -105.0
# -105.0, 105.0
# -105.0, 315.0
# -105.0, 525.0
# -105.0, 735.0
# -105.0, 945.0
# 105.0, 945.0
# 105.0, 735.0
# 105.0, 525.0
# 105.0, 315.0
# 105.0, 105.0
# 105.0, -105.0
# 105.0, -315.0
# 105.0, -525.0
# 105.0, -735.0
# 105.0, -945.0
# 315.0, -945.0
# 315.0, -735.0
# 315.0, -525.0
# 315.0, -315.0
# 315.0, -105.0
# 315.0, 105.0
# 315.0, 315.0
# 315.0, 525.0
# 315.0, 735.0
# 315.0, 945.0
# 525.0, 945.0
# 525.0, 735.0
# 525.0, 525.0
# 525.0, 315.0
# 525.0, 105.0
# 525.0, -105.0
# 525.0, -315.0
# 525.0, -525.0
# 525.0, -735.0
# 525.0, -945.0
# 735.0, -945.0
# 735.0, -735.0
# 735.0, -525.0
# 735.0, -315.0
# 735.0, -105.0
# 735.0, 105.0
# 735.0, 315.0
# 735.0, 525.0
# 735.0, 735.0
# 735.0, 945.0
# 945.0, 945.0
# 945.0, 735.0
# 945.0, 525.0
# 945.0, 315.0
# 945.0, 105.0
# 945.0, -105.0
# 945.0, -315.0
# 945.0, -525.0
# 945.0, -735.0
# 945.0, -945.0

# %%
pos_files = [os.path.join(data_folder, _fl) for _fl in os.listdir(data_folder) if _fl.split(os.extsep)[-1]=='txt']
print(pos_files)
# Out:
# ['D:\\Pu\\20211026-hTERT-WT_SI16-chr21\\positions_all.txt']

# %%
import pandas

all_positions = []
for _fl in pos_files:
    _data_frame = pandas.read_csv(_fl,header=None, names=['X','Y'])
    for _x, _y in zip(_data_frame['X'], _data_frame['Y']):
        all_positions.append([_x,_y])
all_positions = np.round(np.array(all_positions), 2)
print(all_positions)
# Out:
# [[-3749.3 -1790.1]
#  [-3749.3 -1580.1]
#  [-3749.3 -1370.1]
#  [-3749.3 -1160.1]
#  [-3749.3  -950.1]
#  [-3749.3  -740.1]
#  [-3749.3  -530.1]
#  [-3749.3  -320.1]
#  [-3749.3  -110.1]
#  [-3539.3  -110.1]
#  [-3539.3  -320.1]
#  [-3539.3  -530.1]
#  [-3539.3  -740.1]
#  [-3539.3  -950.1]
#  [-3539.3 -1160.1]
#  [-3539.3 -1370.1]
#  [-3539.3 -1580.1]
#  [-3539.3 -1790.1]
#  [-3329.3 -1790.1]
#  [-3329.3 -1580.1]
#  [-3329.3 -1370.1]
#  [-3329.3 -1160.1]
#  [-3329.3  -950.1]
#  [-3329.3  -740.1]
#  [-3329.3  -530.1]
#  [-3329.3  -320.1]
#  [-3329.3  -110.1]
#  [-3119.3  -110.1]
#  [-3119.3  -320.1]
#  [-3119.3  -530.1]
#  [-3119.3  -740.1]
#  [-3119.3  -950.1]
#  [-3119.3 -1160.1]
#  [-3119.3 -1370.1]
#  [-3119.3 -1580.1]
#  [-3119.3 -1790.1]
#  [-1971.  -1937. ]
#  [-1971.  -1727. ]
#  [-1971.  -1517. ]
#  [-1971.  -1307. ]
#  [-1971.  -1097. ]
#  [-1971.   -887. ]
#  [-1971.   -677. ]
#  [-1971.   -467. ]
#  [-1761.   -467. ]
#  [-1761.   -677. ]
#  [-1761.   -887. ]
#  [-1761.  -1097. ]
#  [-1761.  -1307. ]
#  [-1761.  -1517. ]
#  [-1761.  -1727. ]
#  [-1761.  -1937. ]
#  [ -999.9 -1446.3]
#  [ -999.9 -1236.3]
#  [ -999.9 -1026.3]
#  [ -789.9 -1026.3]
#  [ -789.9 -1236.3]
#  [ -789.9 -1446.3]
#  [ -579.9 -1446.3]
#  [ -579.9 -1236.3]
#  [ -579.9 -1026.3]]

# %%
data_folder = r'D:\Shiwei\20210529-P_Forebrain_MERFISH_CTP09_exp2'

all_positions = np.loadtxt(os.path.join(data_folder, 'adjusted_translated_positions_all.txt'), delimiter=',')

# %%
all_positions
# Out:
# array([[-3746.7, -1786.2],
#        [-3746.7, -1576.2],
#        [-3746.7, -1366.2],
#        [-3746.7, -1156.2],
#        [-3746.7,  -946.2],
#        [-3746.7,  -736.2],
#        [-3746.7,  -526.2],
#        [-3746.7,  -316.2],
#        [-3746.7,  -106.2],
#        [-3536.7,  -106.2],
#        [-3536.7,  -316.2],
#        [-3536.7,  -526.2],
#        [-3536.7,  -736.2],
#        [-3536.7,  -946.2],
#        [-3536.7, -1156.2],
#        [-3536.7, -1366.2],
#        [-3536.7, -1576.2],
#        [-3536.7, -1786.2],
#        [-3326.7, -1786.2],
#        [-3326.7, -1576.2],
#        [-3326.7, -1366.2],
#        [-3326.7, -1156.2],
#        [-3326.7,  -946.2],
#        [-3326.7,  -736.2],
#        [-3326.7,  -526.2],
#        [-3326.7,  -316.2],
#        [-3326.7,  -106.2],
#        [-3116.7,  -106.2],
#        [-3116.7,  -316.2],
#        [-3116.7,  -526.2],
#        [-3116.7,  -736.2],
#        [-3116.7,  -946.2],
#        [-3116.7, -1156.2],
#        [-3116.7, -1366.2],
#        [-3116.7, -1576.2],
#        [-3116.7, -1786.2],
#        [-1968.4, -1933.1],
#        [-1968.4, -1723.1],
#        [-1968.4, -1513.1],
#        [-1968.4, -1303.1],
#        [-1968.4, -1093.1],
#        [-1968.4,  -883.1],
#        [-1968.4,  -673.1],
#        [-1968.4,  -463.1],
#        [-1758.4,  -463.1],
#        [-1758.4,  -673.1],
#        [-1758.4,  -883.1],
#        [-1758.4, -1093.1],
#        [-1758.4, -1303.1],
#        [-1758.4, -1513.1],
#        [-1758.4, -1723.1],
#        [-1758.4, -1933.1],
#        [ -997.3, -1442.4],
#        [ -997.3, -1232.4],
#        [ -997.3, -1022.4],
#        [ -787.3, -1022.4],
#        [ -787.3, -1232.4],
#        [ -787.3, -1442.4],
#        [ -577.3, -1442.4],
#        [ -577.3, -1232.4],
#        [ -577.3, -1022.4]])

# %%
# write into a file

all_pos_filename = os.path.join(data_folder, 'adjusted_positions_all.txt')

with open(all_pos_filename, 'w') as _fp:
    for position in all_positions:
        #_fp.write(str(round(position[0],2))+","+str(position[1])+os.linesep) # python2 works
        _fp.write(str(round(position[0],2))+","+str(position[1])+"\n")

# %%
x= " 999"

# %%
float (x)
# Out:
# 999.0

# %%
## test position file loading
filename = r'Z:\20210801-MEF_CTP10_Aire_DNA\Mosiacs\60x_405_mosiac.msc'
line = 'test\n'
with open(filename, 'r') as fp:
    lines = fp.readlines()
    #while len(line) > 0:
    #    line = fp.readline().rstrip()
    #    print(line, len(line))

# %%
lines
# Out:
# ['image,60x_405_mosiac_1.stv\n',
#  '\n',
#  'image,60x_405_mosiac_2.stv\n',
#  '\n',
#  'image,60x_405_mosiac_3.stv\n',
#  '\n',
#  'image,60x_405_mosiac_4.stv\n',
#  '\n',
#  'image,60x_405_mosiac_5.stv\n',
#  '\n',
#  'image,60x_405_mosiac_6.stv\n',
#  '\n',
#  'image,60x_405_mosiac_7.stv\n',
#  '\n',
#  'image,60x_405_mosiac_8.stv\n',
#  '\n',
#  'image,60x_405_mosiac_9.stv\n',
#  '\n',
#  'image,60x_405_mosiac_10.stv\n',
#  '\n',
#  'image,60x_405_mosiac_11.stv\n',
#  '\n',
#  'image,60x_405_mosiac_12.stv\n',
#  '\n',
#  'image,60x_405_mosiac_13.stv\n',
#  '\n',
#  'image,60x_405_mosiac_14.stv\n',
#  '\n',
#  'image,60x_405_mosiac_15.stv\n',
#  '\n',
#  'image,60x_405_mosiac_16.stv\n',
#  '\n',
#  'image,60x_405_mosiac_17.stv\n',
#  '\n',
#  'image,60x_405_mosiac_18.stv\n',
#  '\n',
#  'image,60x_405_mosiac_19.stv\n',
#  '\n',
#  'image,60x_405_mosiac_20.stv\n',
#  '\n',
#  'image,60x_405_mosiac_21.stv\n',
#  '\n',
#  'image,60x_405_mosiac_22.stv\n',
#  '\n',
#  'image,60x_405_mosiac_23.stv\n',
#  '\n',
#  'image,60x_405_mosiac_24.stv\n',
#  '\n',
#  'image,60x_405_mosiac_25.stv\n',
#  '\n',
#  'image,60x_405_mosiac_26.stv\n',
#  '\n',
#  'image,60x_405_mosiac_27.stv\n',
#  '\n',
#  'image,60x_405_mosiac_28.stv\n',
#  '\n',
#  'image,60x_405_mosiac_29.stv\n',
#  '\n',
#  'image,60x_405_mosiac_30.stv\n',
#  '\n',
#  'image,60x_405_mosiac_31.stv\n',
#  '\n',
#  'image,60x_405_mosiac_32.stv\n',
#  '\n',
#  'image,60x_405_mosiac_33.stv\n',
#  '\n',
#  'image,60x_405_mosiac_34.stv\n',
#  '\n',
#  'image,60x_405_mosiac_35.stv\n',
#  '\n',
#  'image,60x_405_mosiac_36.stv\n',
#  '\n',
#  'image,60x_405_mosiac_37.stv\n',
#  '\n',
#  'image,60x_405_mosiac_38.stv\n',
#  '\n',
#  'image,60x_405_mosiac_39.stv\n',
#  '\n',
#  'image,60x_405_mosiac_40.stv\n',
#  '\n',
#  'image,60x_405_mosiac_41.stv\n',
#  '\n',
#  'image,60x_405_mosiac_42.stv\n',
#  '\n',
#  'image,60x_405_mosiac_43.stv\n',
#  '\n',
#  'image,60x_405_mosiac_44.stv\n',
#  '\n',
#  'image,60x_405_mosiac_45.stv\n',
#  '\n',
#  'image,60x_405_mosiac_46.stv\n',
#  '\n',
#  'image,60x_405_mosiac_47.stv\n',
#  '\n',
#  'image,60x_405_mosiac_48.stv\n',
#  '\n',
#  'image,60x_405_mosiac_49.stv\n',
#  '\n',
#  'image,60x_405_mosiac_50.stv\n',
#  '\n',
#  'image,60x_405_mosiac_51.stv\n',
#  '\n',
#  'image,60x_405_mosiac_52.stv\n',
#  '\n',
#  'image,60x_405_mosiac_53.stv\n',
#  '\n',
#  'image,60x_405_mosiac_54.stv\n',
#  '\n',
#  'image,60x_405_mosiac_55.stv\n',
#  '\n',
#  'image,60x_405_mosiac_56.stv\n',
#  '\n',
#  'image,60x_405_mosiac_57.stv\n',
#  '\n',
#  'image,60x_405_mosiac_58.stv\n',
#  '\n',
#  'image,60x_405_mosiac_59.stv\n',
#  '\n',
#  'image,60x_405_mosiac_60.stv\n',
#  '\n',
#  'image,60x_405_mosiac_61.stv\n',
#  '\n',
#  'image,60x_405_mosiac_62.stv\n',
#  '\n',
#  'image,60x_405_mosiac_63.stv\n',
#  '\n',
#  'image,60x_405_mosiac_64.stv\n',
#  '\n',
#  'image,60x_405_mosiac_65.stv\n',
#  '\n',
#  'image,60x_405_mosiac_66.stv\n',
#  '\n',
#  'image,60x_405_mosiac_67.stv\n',
#  '\n',
#  'image,60x_405_mosiac_68.stv\n',
#  '\n',
#  'image,60x_405_mosiac_69.stv\n',
#  '\n',
#  'image,60x_405_mosiac_70.stv\n',
#  '\n',
#  'image,60x_405_mosiac_71.stv\n',
#  '\n',
#  'image,60x_405_mosiac_72.stv\n',
#  '\n',
#  'image,60x_405_mosiac_73.stv\n',
#  '\n',
#  'image,60x_405_mosiac_74.stv\n',
#  '\n',
#  'image,60x_405_mosiac_75.stv\n',
#  '\n',
#  'image,60x_405_mosiac_76.stv\n',
#  '\n',
#  'image,60x_405_mosiac_77.stv\n',
#  '\n',
#  'image,60x_405_mosiac_78.stv\n',
#  '\n',
#  'image,60x_405_mosiac_79.stv\n',
#  '\n',
#  'image,60x_405_mosiac_80.stv\n',
#  '\n',
#  'image,60x_405_mosiac_81.stv\n',
#  '\n',
#  'image,60x_405_mosiac_82.stv\n',
#  '\n',
#  'image,60x_405_mosiac_83.stv\n',
#  '\n',
#  'image,60x_405_mosiac_84.stv\n',
#  '\n',
#  'image,60x_405_mosiac_85.stv\n',
#  '\n',
#  'image,60x_405_mosiac_86.stv\n',
#  '\n',
#  'image,60x_405_mosiac_87.stv\n',
#  '\n',
#  'image,60x_405_mosiac_88.stv\n',
#  '\n',
#  'image,60x_405_mosiac_89.stv\n',
#  '\n',
#  'image,60x_405_mosiac_90.stv\n',
#  '\n',
#  'image,60x_405_mosiac_91.stv\n',
#  '\n',
#  'image,60x_405_mosiac_92.stv\n',
#  '\n',
#  'image,60x_405_mosiac_93.stv\n',
#  '\n',
#  'image,60x_405_mosiac_94.stv\n',
#  '\n',
#  'image,60x_405_mosiac_95.stv\n',
#  '\n',
#  'image,60x_405_mosiac_96.stv\n',
#  '\n',
#  'image,60x_405_mosiac_97.stv\n',
#  '\n',
#  'image,60x_405_mosiac_98.stv\n',
#  '\n',
#  'image,60x_405_mosiac_99.stv\n',
#  '\n',
#  'image,60x_405_mosiac_100.stv\n',
#  '\n',
#  'image,60x_405_mosiac_101.stv\n',
#  '\n',
#  'image,60x_405_mosiac_102.stv\n',
#  '\n',
#  'image,60x_405_mosiac_103.stv\n',
#  '\n',
#  'image,60x_405_mosiac_104.stv\n',
#  '\n',
#  'image,60x_405_mosiac_105.stv\n',
#  '\n',
#  'image,60x_405_mosiac_106.stv\n',
#  '\n',
#  'image,60x_405_mosiac_107.stv\n',
#  '\n',
#  'image,60x_405_mosiac_108.stv\n',
#  '\n',
#  'image,60x_405_mosiac_109.stv\n',
#  '\n',
#  'image,60x_405_mosiac_110.stv\n',
#  '\n',
#  'image,60x_405_mosiac_111.stv\n',
#  '\n',
#  'image,60x_405_mosiac_112.stv\n',
#  '\n',
#  'image,60x_405_mosiac_113.stv\n',
#  '\n',
#  'image,60x_405_mosiac_114.stv\n',
#  '\n',
#  'image,60x_405_mosiac_115.stv\n',
#  '\n',
#  'image,60x_405_mosiac_116.stv\n',
#  '\n',
#  'image,60x_405_mosiac_117.stv\n',
#  '\n',
#  'image,60x_405_mosiac_118.stv\n',
#  '\n',
#  'image,60x_405_mosiac_119.stv\n',
#  '\n',
#  'image,60x_405_mosiac_120.stv\n',
#  '\n',
#  'image,60x_405_mosiac_121.stv\n',
#  '\n',
#  'image,60x_405_mosiac_122.stv\n',
#  '\n',
#  'image,60x_405_mosiac_123.stv\n',
#  '\n',
#  'image,60x_405_mosiac_124.stv\n',
#  '\n',
#  'image,60x_405_mosiac_125.stv\n',
#  '\n',
#  'image,60x_405_mosiac_126.stv\n',
#  '\n',
#  'image,60x_405_mosiac_127.stv\n',
#  '\n',
#  'image,60x_405_mosiac_128.stv\n',
#  '\n',
#  'image,60x_405_mosiac_129.stv\n',
#  '\n',
#  'image,60x_405_mosiac_130.stv\n',
#  '\n',
#  'image,60x_405_mosiac_131.stv\n',
#  '\n',
#  'image,60x_405_mosiac_132.stv\n',
#  '\n',
#  'image,60x_405_mosiac_133.stv\n',
#  '\n',
#  'image,60x_405_mosiac_134.stv\n',
#  '\n',
#  'image,60x_405_mosiac_135.stv\n',
#  '\n',
#  'image,60x_405_mosiac_136.stv\n',
#  '\n',
#  'image,60x_405_mosiac_137.stv\n',
#  '\n',
#  'image,60x_405_mosiac_138.stv\n',
#  '\n',
#  'image,60x_405_mosiac_139.stv\n',
#  '\n',
#  'image,60x_405_mosiac_140.stv\n',
#  '\n',
#  'image,60x_405_mosiac_141.stv\n',
#  '\n',
#  'image,60x_405_mosiac_142.stv\n',
#  '\n',
#  'image,60x_405_mosiac_143.stv\n',
#  '\n',
#  'image,60x_405_mosiac_144.stv\n',
#  '\n',
#  'image,60x_405_mosiac_145.stv\n',
#  '\n',
#  'image,60x_405_mosiac_146.stv\n',
#  '\n',
#  'image,60x_405_mosiac_147.stv\n',
#  '\n',
#  'image,60x_405_mosiac_148.stv\n',
#  '\n',
#  'image,60x_405_mosiac_149.stv\n',
#  '\n',
#  'image,60x_405_mosiac_150.stv\n',
#  '\n',
#  'image,60x_405_mosiac_151.stv\n',
#  '\n',
#  'image,60x_405_mosiac_152.stv\n',
#  '\n',
#  'image,60x_405_mosiac_153.stv\n',
#  '\n',
#  'image,60x_405_mosiac_154.stv\n',
#  '\n',
#  'image,60x_405_mosiac_155.stv\n',
#  '\n',
#  'image,60x_405_mosiac_156.stv\n',
#  '\n',
#  'image,60x_405_mosiac_157.stv\n',
#  '\n',
#  'image,60x_405_mosiac_158.stv\n',
#  '\n',
#  'image,60x_405_mosiac_159.stv\n',
#  '\n',
#  'image,60x_405_mosiac_160.stv\n',
#  '\n',
#  'image,60x_405_mosiac_161.stv\n',
#  '\n',
#  'image,60x_405_mosiac_162.stv\n',
#  '\n',
#  'image,60x_405_mosiac_163.stv\n',
#  '\n',
#  'image,60x_405_mosiac_164.stv\n',
#  '\n',
#  'image,60x_405_mosiac_165.stv\n',
#  '\n',
#  'image,60x_405_mosiac_166.stv\n',
#  '\n',
#  'image,60x_405_mosiac_167.stv\n',
#  '\n',
#  'image,60x_405_mosiac_168.stv\n',
#  '\n',
#  'image,60x_405_mosiac_169.stv\n',
#  '\n',
#  'image,60x_405_mosiac_170.stv\n',
#  '\n',
#  'image,60x_405_mosiac_171.stv\n',
#  '\n',
#  'image,60x_405_mosiac_172.stv\n',
#  '\n',
#  'image,60x_405_mosiac_173.stv\n',
#  '\n',
#  'image,60x_405_mosiac_174.stv\n',
#  '\n',
#  'image,60x_405_mosiac_175.stv\n',
#  '\n',
#  'image,60x_405_mosiac_176.stv\n',
#  '\n',
#  'image,60x_405_mosiac_177.stv\n',
#  '\n',
#  'image,60x_405_mosiac_178.stv\n',
#  '\n',
#  'image,60x_405_mosiac_179.stv\n',
#  '\n',
#  'image,60x_405_mosiac_180.stv\n',
#  '\n',
#  'image,60x_405_mosiac_181.stv\n',
#  '\n',
#  'image,60x_405_mosiac_182.stv\n',
#  '\n',
#  'image,60x_405_mosiac_183.stv\n',
#  '\n',
#  'image,60x_405_mosiac_184.stv\n',
#  '\n',
#  'image,60x_405_mosiac_185.stv\n',
#  '\n',
#  'image,60x_405_mosiac_186.stv\n',
#  '\n',
#  'image,60x_405_mosiac_187.stv\n',
#  '\n',
#  'image,60x_405_mosiac_188.stv\n',
#  '\n',
#  'image,60x_405_mosiac_189.stv\n',
#  '\n',
#  'image,60x_405_mosiac_190.stv\n',
#  '\n',
#  'image,60x_405_mosiac_191.stv\n',
#  '\n',
#  'image,60x_405_mosiac_192.stv\n',
#  '\n',
#  'image,60x_405_mosiac_193.stv\n',
#  '\n',
#  'image,60x_405_mosiac_194.stv\n',
#  '\n',
#  'image,60x_405_mosiac_195.stv\n',
#  '\n',
#  'image,60x_405_mosiac_196.stv\n',
#  '\n',
#  'image,60x_405_mosiac_197.stv\n',
#  '\n',
#  'image,60x_405_mosiac_198.stv\n',
#  '\n',
#  'image,60x_405_mosiac_199.stv\n',
#  '\n',
#  'image,60x_405_mosiac_200.stv\n',
#  '\n',
#  'image,60x_405_mosiac_201.stv\n',
#  '\n',
#  'image,60x_405_mosiac_202.stv\n',
#  '\n',
#  'image,60x_405_mosiac_203.stv\n',
#  '\n',
#  'image,60x_405_mosiac_204.stv\n',
#  '\n',
#  'image,60x_405_mosiac_205.stv\n',
#  '\n',
#  'image,60x_405_mosiac_206.stv\n',
#  '\n',
#  'image,60x_405_mosiac_207.stv\n',
#  '\n',
#  'image,60x_405_mosiac_208.stv\n',
#  '\n',
#  'image,60x_405_mosiac_209.stv\n',
#  '\n',
#  'image,60x_405_mosiac_210.stv\n',
#  '\n',
#  'image,60x_405_mosiac_211.stv\n',
#  '\n',
#  'image,60x_405_mosiac_212.stv\n',
#  '\n',
#  'image,60x_405_mosiac_213.stv\n',
#  '\n',
#  'image,60x_405_mosiac_214.stv\n',
#  '\n',
#  'image,60x_405_mosiac_215.stv\n',
#  '\n',
#  'image,60x_405_mosiac_216.stv\n',
#  '\n',
#  'image,60x_405_mosiac_217.stv\n',
#  '\n',
#  'image,60x_405_mosiac_218.stv\n',
#  '\n',
#  'image,60x_405_mosiac_219.stv\n',
#  '\n',
#  'image,60x_405_mosiac_220.stv\n',
#  '\n',
#  'image,60x_405_mosiac_221.stv\n',
#  '\n',
#  'image,60x_405_mosiac_222.stv\n',
#  '\n',
#  'image,60x_405_mosiac_223.stv\n',
#  '\n',
#  'image,60x_405_mosiac_224.stv\n',
#  '\n',
#  'image,60x_405_mosiac_225.stv\n',
#  '\n',
#  'image,60x_405_mosiac_226.stv\n',
#  '\n',
#  'image,60x_405_mosiac_227.stv\n',
#  '\n',
#  'image,60x_405_mosiac_228.stv\n',
#  '\n',
#  'image,60x_405_mosiac_229.stv\n',
#  '\n',
#  'image,60x_405_mosiac_230.stv\n',
#  '\n',
#  'image,60x_405_mosiac_231.stv\n',
#  '\n',
#  'image,60x_405_mosiac_232.stv\n',
#  '\n',
#  'image,60x_405_mosiac_233.stv\n',
#  '\n',
#  'image,60x_405_mosiac_234.stv\n',
#  '\n',
#  'image,60x_405_mosiac_235.stv\n',
#  '\n',
#  'image,60x_405_mosiac_236.stv\n',
#  '\n',
#  'image,60x_405_mosiac_237.stv\n',
#  '\n',
#  'image,60x_405_mosiac_238.stv\n',
#  '\n',
#  'image,60x_405_mosiac_239.stv\n',
#  '\n',
#  'image,60x_405_mosiac_240.stv\n',
#  '\n',
#  'image,60x_405_mosiac_241.stv\n',
#  '\n',
#  'image,60x_405_mosiac_242.stv\n',
#  '\n',
#  'image,60x_405_mosiac_243.stv\n',
#  '\n',
#  'image,60x_405_mosiac_244.stv\n',
#  '\n',
#  'image,60x_405_mosiac_245.stv\n',
#  '\n',
#  'image,60x_405_mosiac_246.stv\n',
#  '\n',
#  'image,60x_405_mosiac_247.stv\n',
#  '\n',
#  'image,60x_405_mosiac_248.stv\n',
#  '\n',
#  'image,60x_405_mosiac_249.stv\n',
#  '\n',
#  'image,60x_405_mosiac_250.stv\n',
#  '\n',
#  'image,60x_405_mosiac_251.stv\n',
#  '\n',
#  'image,60x_405_mosiac_252.stv\n',
#  '\n',
#  'image,60x_405_mosiac_253.stv\n',
#  '\n',
#  'image,60x_405_mosiac_254.stv\n',
#  '\n',
#  'image,60x_405_mosiac_255.stv\n',
#  '\n',
#  'image,60x_405_mosiac_256.stv\n',
#  '\n',
#  'image,60x_405_mosiac_257.stv\n',
#  '\n',
#  'image,60x_405_mosiac_258.stv\n',
#  '\n',
#  'image,60x_405_mosiac_259.stv\n',
#  '\n',
#  'image,60x_405_mosiac_260.stv\n',
#  '\n',
#  'image,60x_405_mosiac_261.stv\n',
#  '\n',
#  'image,60x_405_mosiac_262.stv\n',
#  '\n',
#  'image,60x_405_mosiac_263.stv\n',
#  '\n',
#  'image,60x_405_mosiac_264.stv\n',
#  '\n',
#  'image,60x_405_mosiac_265.stv\n',
#  '\n',
#  'image,60x_405_mosiac_266.stv\n',
#  '\n',
#  'image,60x_405_mosiac_267.stv\n',
#  '\n',
#  'image,60x_405_mosiac_268.stv\n',
#  '\n',
#  'image,60x_405_mosiac_269.stv\n',
#  '\n',
#  'image,60x_405_mosiac_270.stv\n',
#  '\n',
#  'image,60x_405_mosiac_271.stv\n',
#  '\n',
#  'image,60x_405_mosiac_272.stv\n',
#  '\n',
#  'image,60x_405_mosiac_273.stv\n',
#  '\n',
#  'image,60x_405_mosiac_274.stv\n',
#  '\n',
#  'image,60x_405_mosiac_275.stv\n',
#  '\n',
#  'image,60x_405_mosiac_276.stv\n',
#  '\n',
#  'image,60x_405_mosiac_277.stv\n',
#  '\n',
#  'image,60x_405_mosiac_278.stv\n',
#  '\n',
#  'image,60x_405_mosiac_279.stv\n',
#  '\n',
#  'image,60x_405_mosiac_280.stv\n',
#  '\n',
#  'image,60x_405_mosiac_281.stv\n',
#  '\n',
#  'image,60x_405_mosiac_282.stv\n',
#  '\n',
#  'image,60x_405_mosiac_283.stv\n',
#  '\n',
#  'image,60x_405_mosiac_284.stv\n',
#  '\n',
#  'image,60x_405_mosiac_285.stv\n',
#  '\n',
#  'image,60x_405_mosiac_286.stv\n',
#  '\n',
#  'image,60x_405_mosiac_287.stv\n',
#  '\n',
#  'image,60x_405_mosiac_288.stv\n',
#  '\n',
#  'image,60x_405_mosiac_289.stv\n',
#  '\n',
#  'image,60x_405_mosiac_290.stv\n',
#  '\n',
#  'image,60x_405_mosiac_291.stv\n',
#  '\n',
#  'image,60x_405_mosiac_292.stv\n',
#  '\n',
#  'image,60x_405_mosiac_293.stv\n',
#  '\n',
#  'image,60x_405_mosiac_294.stv\n',
#  '\n',
#  'image,60x_405_mosiac_295.stv\n',
#  '\n',
#  'image,60x_405_mosiac_296.stv\n',
#  '\n',
#  'image,60x_405_mosiac_297.stv\n',
#  '\n',
#  'image,60x_405_mosiac_298.stv\n',
#  '\n',
#  'image,60x_405_mosiac_299.stv\n',
#  '\n',
#  'image,60x_405_mosiac_300.stv\n',
#  '\n',
#  'image,60x_405_mosiac_301.stv\n',
#  '\n',
#  'image,60x_405_mosiac_302.stv\n',
#  '\n',
#  'image,60x_405_mosiac_303.stv\n',
#  '\n',
#  'image,60x_405_mosiac_304.stv\n',
#  '\n',
#  'image,60x_405_mosiac_305.stv\n',
#  '\n',
#  'image,60x_405_mosiac_306.stv\n',
#  '\n',
#  'image,60x_405_mosiac_307.stv\n',
#  '\n',
#  'image,60x_405_mosiac_308.stv\n',
#  '\n',
#  'image,60x_405_mosiac_309.stv\n',
#  '\n',
#  'image,60x_405_mosiac_310.stv\n',
#  '\n',
#  'image,60x_405_mosiac_311.stv\n',
#  '\n',
#  'image,60x_405_mosiac_312.stv\n',
#  '\n',
#  'image,60x_405_mosiac_313.stv\n',
#  '\n',
#  'image,60x_405_mosiac_314.stv\n',
#  '\n',
#  'image,60x_405_mosiac_315.stv\n',
#  '\n',
#  'image,60x_405_mosiac_316.stv\n',
#  '\n',
#  'image,60x_405_mosiac_317.stv\n',
#  '\n',
#  'image,60x_405_mosiac_318.stv\n',
#  '\n',
#  'image,60x_405_mosiac_319.stv\n',
#  '\n',
#  'image,60x_405_mosiac_320.stv\n',
#  '\n',
#  'image,60x_405_mosiac_321.stv\n',
#  '\n',
#  'image,60x_405_mosiac_322.stv\n',
#  '\n',
#  'image,60x_405_mosiac_323.stv\n',
#  '\n',
#  'image,60x_405_mosiac_324.stv\n',
#  '\n',
#  'position,878.57, -1143.74\n',
#  '\n',
#  'position,1201.24, -1357.79\n',
#  '\n',
#  'position,396.16, -645.35\n',
#  '\n',
#  'position,118.21, -581.45\n',
#  '\n',
#  'position,323.92, -237.39\n',
#  '\n',
#  'position,137.55, 93.18\n',
#  '\n',
#  'position,-108.71, 452.60\n',
#  '\n',
#  'position,-37.72, 674.46\n',
#  '\n',
#  'position,130.90, 967.31\n',
#  '\n',
#  'position,590.15, 860.82\n',
#  '\n',
#  'position,685.55, 658.93\n',
#  '\n',
#  'position,794.26, 423.75\n',
#  '\n',
#  'position,1109.31, 689.99\n',
#  '\n',
#  'position,1040.53, 1064.93\n',
#  '\n',
#  'position,1295.67, 1304.54\n',
#  '\n',
#  'position,1610.71, 1127.05\n',
#  '\n',
#  'position,1419.91, 973.97\n',
#  '\n',
#  'position,1828.14, 856.38\n',
#  '\n',
#  'position,2016.72, 601.24\n',
#  '\n',
#  'position,1794.86, 454.82\n',
#  '\n',
#  'position,1976.78, 246.27\n',
#  '\n',
#  'position,1874.73, -161.96\n',
#  '\n',
#  'position,2076.62, -576.84\n',
#  '\n',
#  'position,2285.17, 144.21\n',
#  '\n',
#  'position,2249.67, 350.54\n',
#  '\n',
#  'position,2866.45, 164.18\n',
#  '\n',
#  'position,2924.13, -128.68\n',
#  '\n',
#  'position,3077.21, -232.95\n',
#  '\n',
#  'position,3390.04, -379.38\n',
#  '\n',
#  'position,2475.97, -707.74\n',
#  '\n',
#  'position,1679.49, -1189.18\n',
#  '\n',
#  'position,2864.23, -1171.43\n',
#  '\n',
#  'position,2673.43, -1453.19\n',
#  '\n',
#  'position,2444.91, -1546.37\n',
#  '\n',
#  'position,2205.30, -1364.45\n',
#  '\n',
#  'position,1981.22, -1353.35\n',
#  '\n',
#  'position,2640.15, -1790.42\n',
#  '\n',
#  'position,3163.74, -2152.05\n',
#  '\n',
#  'position,2580.24, -2012.28\n',
#  '\n',
#  'position,2309.57, -1945.72\n',
#  '\n',
#  'position,1896.91, -1848.10\n',
#  '\n',
#  'position,1766.01, -2083.28\n',
#  '\n',
#  'position,1475.38, -2023.37\n',
#  '\n',
#  'position,1020.56, -1690.58\n',
#  '\n',
#  'position,685.55, -1459.85\n',
#  '\n']

# %%
line.rstrip()
# Out:
# 'test'
