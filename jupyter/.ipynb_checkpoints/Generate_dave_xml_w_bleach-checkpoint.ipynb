# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os
valve_ids = np.arange(4,18+1)
hyb_ids = np.arange(4,18+1)
reg_names = [f'u{_i}' for _i in np.arange(1,15+1)]

# %%
source_folder = r'D:\Shiwei\20210706-P_Forebrain_CTP09_only'
target_drive = r'\\KOLMOGOROV\Chromatin_NAS_5'
imaging_protocol = r'Zscan_750_647_488_s60_n200'

# %%
cmd_seq = Element('command_sequence')

for _vid, _hid, _rname in zip(valve_ids, hyb_ids, reg_names):
    # comments
    comment = Comment(f"Hyb {_hid} for {_rname}")
    cmd_seq.append(comment)
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "Flow TCEP"
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'delay')
    adt_incubation.text = "600000"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Short Wash"
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    readouts.text = "Flow Readouts"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'delay')
    adt_incubation.text = "600000"
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    
    # hybridization loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=imaging_protocol)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)

# %%
print( prettify(cmd_seq))
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 33 for u33-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H33U33</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H33U33</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H33U33</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 34 for u34-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H34U34</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H34U34</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H34U34</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 35 for u35-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H35U35</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H35U35</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H35U35</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 36 for u36-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H36U36</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H36U36</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H36U36</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 37 for u37-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H37U37</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H37U37</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H37U37</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 38 for u38-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H38U38</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H38U38</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H38U38</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 39 for u39-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H39U39</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H39U39</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H39U39</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 40 for u40-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H40U40</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H40U40</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H40U40</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 41 for u41-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H41U41</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H41U41</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H41U41</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 42 for u42-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H42U42</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H42U42</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H42U42</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 43 for u43-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H43U43</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H43U43</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H43U43</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 44 for u44-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H44U44</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H44U44</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H44U44</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 45 for u45-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 13</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H45U45</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H45U45</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H45U45</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 46 for u46-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 14</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H46U46</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H46U46</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H46U46</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 47 for u47-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 15</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H47U47</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H47U47</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H47U47</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 48 for u48-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 16</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H48U48</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H48U48</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H48U48</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# </command_sequence>
