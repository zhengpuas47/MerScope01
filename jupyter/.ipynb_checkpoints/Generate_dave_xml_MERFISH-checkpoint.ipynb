# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os
valve_ids = np.arange(2,11+1)
hyb_ids = np.arange(2,11+1)
reg_names = [f'M{_i}_bit{_i*2-1}-{_i*2}' for _i in np.arange(2,11+1)]

# %%
source_folder = r'D:\Pu\20210717-P_brain_MO4_MERFISH'
target_drive = r'\\KOLMOGOROV\Chromatin_NAS_5'
imaging_protocol = r'Conv_Zscan_750_647_561_s13_n1000_5Hz'

# %%
cmd_seq = Element('command_sequence')

for _vid, _hid, _rname in zip(valve_ids, hyb_ids, reg_names):
    # comments
    comment = Comment(f"Hyb {_hid} for {_rname}")
    cmd_seq.append(comment)
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "MERFISH TCEP"
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'delay')
    adt_incubation.text = "600000"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "MERFISH Wash"
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    readouts.text = "Flow STORM Buffer"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'delay')
    adt_incubation.text = "60000"
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    
    # hybridization loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=imaging_protocol)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "5000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)

# %%
print( prettify(cmd_seq))
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 2 for M2_bit3-4-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H2M2_BIT3-4</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H2M2_BIT3-4</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H2M2_BIT3-4</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 3 for M3_bit5-6-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H3M3_BIT5-6</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H3M3_BIT5-6</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H3M3_BIT5-6</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 4 for M4_bit7-8-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H4M4_BIT7-8</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H4M4_BIT7-8</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H4M4_BIT7-8</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 5 for M5_bit9-10-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H5M5_BIT9-10</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H5M5_BIT9-10</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H5M5_BIT9-10</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 6 for M6_bit11-12-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H6M6_BIT11-12</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H6M6_BIT11-12</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H6M6_BIT11-12</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 7 for M7_bit13-14-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H7M7_BIT13-14</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H7M7_BIT13-14</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H7M7_BIT13-14</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 8 for M8_bit15-16-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H8M8_BIT15-16</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H8M8_BIT15-16</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H8M8_BIT15-16</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 9 for M9_bit17-18-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H9M9_BIT17-18</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H9M9_BIT17-18</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H9M9_BIT17-18</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 10 for M10_bit19-20-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H10M10_BIT19-20</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H10M10_BIT19-20</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H10M10_BIT19-20</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<!--Hyb 11 for M11_bit21-22-->
# 	<valve_protocol>MERFISH TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>MERFISH Wash</valve_protocol>
# 	<valve_protocol>Flow STORM Buffer</valve_protocol>
# 	<delay>60000</delay>
# 	<change_directory>D:\Pu\20210717-P_brain_MO4_MERFISH\H11M11_BIT21-22</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>5000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210717-P_brain_MO4_MERFISH\H11M11_BIT21-22</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH\H11M11_BIT21-22</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# </command_sequence>
