# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

import numpy as np
import os

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
## Parameters
# data folder
source_folder = r'E:\Data\20240525-F332Lung_MF4dna_bindsaline'
# target saving folder on the storage server
target_drive = r'\\everest\weissman_imaging\puzheng\4T1Tumor'

# step size 
num_steps = 11
step_size = 1200 # nm 
frequency = 5 # Hz

# HAL imaging protocol
imaging_protocol = f'Conv_zscan_748_637_477_s{num_steps}_n{step_size}_{frequency}Hz'
# HAL imaging protocol in the reference round, usually Hyb 0
ref_hyb = 17
ref_imaging_protocol = f'Conv_zscan_748_637_477_405_s{num_steps}_n{step_size}_{frequency}Hz'
# HAL
polyt_hyb = 25
polyt_valve = 26
polyt_imaging_protocol = f'Conv_zscan_748_637_477_s{num_steps}_n{step_size}_{frequency}Hz_low'
if polyt_hyb == ref_hyb:
    raise ValueError("polyT round shouldnt be ref")

# %%
## Paramerters 2: change according to experiment design:
valve_start = 17

hyb_start = 17

reg_start = 1

num_rounds = 8 #+ 1

#data_type = 'R'
data_type = 'M'

valve_ids = np.arange(valve_start, valve_start + num_rounds)
hyb_ids = np.arange(hyb_start, hyb_start + num_rounds)
folder_names = [f'H{_h}{data_type}{_r}' for _h, _r in zip(np.arange(hyb_start, hyb_start + num_rounds), 
                                                     np.arange(reg_start, reg_start + num_rounds))]
print(folder_names)
# Out:
# ['H17M1', 'H18M2', 'H19M3', 'H20M4', 'H21M5', 'H22M6', 'H23M7', 'H24M8']

# %%
recipe = Element('recipe')
cmd_seq = SubElement(recipe, 'command_sequence')

copy_data = True

for _i, (_vid, _hid, _folder) in enumerate(zip(valve_ids, hyb_ids, folder_names)):

    if _hid == ref_hyb:
        # determine ref_imaging protocol
        _im_p = ref_imaging_protocol
        # add hyb 0
        # comments
        comment = Comment(f"Ref Hyb {_hid} in folder: {_folder}")
        cmd_seq.append(comment)
    else:
        if _hid == polyt_hyb:
            _im_p = polyt_imaging_protocol
        else:
            _im_p = imaging_protocol
        # Add TCEP
        if _i > 0 or (_i==0 and _hid >0):
            # TCEP
            tcep = SubElement(cmd_seq, 'valve_protocol')
            tcep.text = "Flow TCEP"
            # wash tcep
            tcep_wash = SubElement(cmd_seq, 'valve_protocol')
            tcep_wash.text = "Flow Wash"
            indent(tcep_wash)
        # comments
        if _hid == polyt_hyb:
            comment = Comment(f"PolyT, Hyb {_hid} with tube:{_vid} in folder: {_folder}")
        else:
            comment = Comment(f"Hyb {_hid} with tube:{_vid} in folder: {_folder}")
        
        cmd_seq.append(comment)
        # Adaptor
        adt = SubElement(cmd_seq, 'valve_protocol')  
        if _hid == polyt_hyb:
            adt.text = f"Flow Hyb {polyt_valve}"
        else:
            adt.text = f"Flow Hyb {_vid}"
        # delay time
        adt_incubation = SubElement(cmd_seq, 'valve_protocol')
        adt_incubation.text = f"Incubate 15min"
        # wash adaptors
        adt_wash = SubElement(cmd_seq, 'valve_protocol')
        adt_wash.text = "Flow Wash"
        
        # Readouts
        readouts = SubElement(cmd_seq, 'valve_protocol')
        readouts.text = "Flow Common Readouts"
        # incubate readouts
        readout_incubation = SubElement(cmd_seq, 'valve_protocol')
        readout_incubation.text = f"Incubate 15min"
        # wash readouts
        readout_wash = SubElement(cmd_seq, 'valve_protocol')
        readout_wash.text = f"Flow Wash"
        
    ## For all rounds, imaging buffer and imaging loop and data copy is required:
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging"
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, _folder)
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    # imaging loop    
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    if copy_data:
    # copy folder
        copy_dir = SubElement(cmd_seq, 'copy_directory')
        source_dir = SubElement(copy_dir, 'source_path')
        source_dir.text = change_dir.text 
        target_dir = SubElement(copy_dir, 'target_path')
        target_dir.text = os.path.join(target_drive, 
                                       os.path.basename(os.path.dirname(source_dir.text)), 
                                       os.path.basename(source_dir.text))
        del_source = SubElement(copy_dir, 'delete_source')
        del_source.text = "True"

ssc = SubElement(cmd_seq, 'valve_protocol')
ssc.text = f"Flow 2xSSC"

#final_str = prettify(cmd_seq)    
#print( final_str )

# %%
# add supplementary scripts
import re
protocol = imaging_protocol
channels = [_s for _s in protocol.split('_') if re.match('^[0-9]+$', _s, )]
steps = int(re.search(r'_s([0-9]+)_', protocol).groups()[0])

hal_item = SubElement(recipe, 'item', name=f"{protocol}")
movie = SubElement(hal_item, 'movie')
name = SubElement(movie, 'name', increment="Yes")
name.text = f"Conv_zscan"
overwrite = SubElement(movie, 'overwrite')
overwrite.text = "True"
length = SubElement(movie, 'length')
length.text = f"{steps * len(channels)}"
parameters = SubElement(movie, 'parameters')
parameters.text = f"{protocol}"
delay = SubElement(movie, 'delay')
delay.text = f"{500}"
check_focus = SubElement(movie, 'check_focus')
num_focus_checks = SubElement(check_focus, 'num_focus_checks')
num_focus_checks.text = f"{100}"
focus_scan = SubElement(check_focus, 'focus_scan')
variable_entry = SubElement(movie, 'variable_entry', name= "Position Loop Zscan")
variable_entry.text = f"{protocol}"

# %%
# add supplementary scripts
import re
protocol = ref_imaging_protocol
channels = [_s for _s in protocol.split('_') if re.match('^[0-9]+$', _s, )]
steps = int(re.search(r'_s([0-9]+)_', protocol).groups()[0])

hal_item = SubElement(recipe, 'item', name=f"{protocol}")
movie = SubElement(hal_item, 'movie')
name = SubElement(movie, 'name', increment="Yes")
name.text = f"Conv_zscan"
overwrite = SubElement(movie, 'overwrite')
overwrite.text = "True"
length = SubElement(movie, 'length')
length.text = f"{steps * len(channels)}"
parameters = SubElement(movie, 'parameters')
parameters.text = f"{protocol}"
delay = SubElement(movie, 'delay')
delay.text = f"{500}"
check_focus = SubElement(movie, 'check_focus')
num_focus_checks = SubElement(check_focus, 'num_focus_checks')
num_focus_checks.text = f"{100}"
focus_scan = SubElement(check_focus, 'focus_scan')
variable_entry = SubElement(movie, 'variable_entry', name= "Position Loop Zscan")
variable_entry.text = f"{protocol}"

# %%
# add supplementary scripts
import re
protocol = polyt_imaging_protocol
channels = [_s for _s in protocol.split('_') if re.match('^[0-9]+$', _s, )]
steps = int(re.search(r'_s([0-9]+)_', protocol).groups()[0])

hal_item = SubElement(recipe, 'item', name=f"{protocol}")
movie = SubElement(hal_item, 'movie')
name = SubElement(movie, 'name', increment="Yes")
name.text = f"Conv_zscan"
overwrite = SubElement(movie, 'overwrite')
overwrite.text = "True"
length = SubElement(movie, 'length')
length.text = f"{steps * len(channels)}"
parameters = SubElement(movie, 'parameters')
parameters.text = f"{protocol}"
delay = SubElement(movie, 'delay')
delay.text = f"{500}"
check_focus = SubElement(movie, 'check_focus')
num_focus_checks = SubElement(check_focus, 'num_focus_checks')
num_focus_checks.text = f"{100}"
focus_scan = SubElement(check_focus, 'focus_scan')
variable_entry = SubElement(movie, 'variable_entry', name= "Position Loop Zscan")
variable_entry.text = f"{protocol}"

# %%
# add loop
loop_variable = SubElement(recipe, 'loop_variable', name=f"Position Loop Zscan")
file_path = SubElement(loop_variable, 'file_path')
file_path.text = "positions_all.txt"

# %%
final_str = prettify(recipe)

# %%
print(final_str)
# Out:
# <?xml version="1.0" ?>
# <recipe>
# 	<command_sequence>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 17 with tube:17 in folder: H17M1-->
# 		<valve_protocol>Flow Hyb 17</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H17M1</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H17M1</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H17M1</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 18 with tube:18 in folder: H18M2-->
# 		<valve_protocol>Flow Hyb 18</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H18M2</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H18M2</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H18M2</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 19 with tube:19 in folder: H19M3-->
# 		<valve_protocol>Flow Hyb 19</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H19M3</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H19M3</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H19M3</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 20 with tube:20 in folder: H20M4-->
# 		<valve_protocol>Flow Hyb 20</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H20M4</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H20M4</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H20M4</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 21 with tube:21 in folder: H21M5-->
# 		<valve_protocol>Flow Hyb 21</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H21M5</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H21M5</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H21M5</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 22 with tube:22 in folder: H22M6-->
# 		<valve_protocol>Flow Hyb 22</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H22M6</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H22M6</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H22M6</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 23 with tube:23 in folder: H23M7-->
# 		<valve_protocol>Flow Hyb 23</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H23M7</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H23M7</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H23M7</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--Hyb 24 with tube:24 in folder: H24M8-->
# 		<valve_protocol>Flow Hyb 24</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H24M8</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H24M8</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H24M8</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow TCEP</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<!--PolyT, Hyb 25 with tube:25 in folder: H25M9-->
# 		<valve_protocol>Flow Hyb 26</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Common Readouts</valve_protocol>
# 		<valve_protocol>Incubate 15min</valve_protocol>
# 		<valve_protocol>Flow Wash</valve_protocol>
# 		<valve_protocol>Flow Imaging</valve_protocol>
# 		<change_directory>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H25M9</change_directory>
# 		<wakeup>5000</wakeup>
# 		<loop name="Position Loop Zscan" increment="name">
# 			<item name="Conv_zscan_748_637_477_s18_n1200_5Hz_low"> </item>
# 		</loop>
# 		<delay>2000</delay>
# 		<copy_directory>
# 			<source_path>E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H25M9</source_path>
# 			<target_path>\\everest\weissman_imaging\puzheng\PE_LT\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\H25M9</target_path>
# 			<delete_source>True</delete_source>
# 		</copy_directory>
# 		<valve_protocol>Flow 2xSSC</valve_protocol>
# 	</command_sequence>
# 	<item name="Conv_zscan_748_637_477_s18_n1200_5Hz">
# 		<movie>
# 			<name increment="Yes">Conv_zscan</name>
# 			<overwrite>True</overwrite>
# 			<length>54</length>
# 			<parameters>Conv_zscan_748_637_477_s18_n1200_5Hz</parameters>
# 			<delay>500</delay>
# 			<check_focus>
# 				<num_focus_checks>100</num_focus_checks>
# 				<focus_scan/>
# 			</check_focus>
# 			<variable_entry name="Position Loop Zscan">Conv_zscan_748_637_477_s18_n1200_5Hz</variable_entry>
# 		</movie>
# 	</item>
# 	<item name="Conv_zscan_748_637_477_405_s18_n1200_5Hz">
# 		<movie>
# 			<name increment="Yes">Conv_zscan</name>
# 			<overwrite>True</overwrite>
# 			<length>72</length>
# 			<parameters>Conv_zscan_748_637_477_405_s18_n1200_5Hz</parameters>
# 			<delay>500</delay>
# 			<check_focus>
# 				<num_focus_checks>100</num_focus_checks>
# 				<focus_scan/>
# 			</check_focus>
# 			<variable_entry name="Position Loop Zscan">Conv_zscan_748_637_477_405_s18_n1200_5Hz</variable_entry>
# 		</movie>
# 	</item>
# 	<item name="Conv_zscan_748_637_477_s18_n1200_5Hz_low">
# 		<movie>
# 			<name increment="Yes">Conv_zscan</name>
# 			<overwrite>True</overwrite>
# 			<length>54</length>
# 			<parameters>Conv_zscan_748_637_477_s18_n1200_5Hz_low</parameters>
# 			<delay>500</delay>
# 			<check_focus>
# 				<num_focus_checks>100</num_focus_checks>
# 				<focus_scan/>
# 			</check_focus>
# 			<variable_entry name="Position Loop Zscan">Conv_zscan_748_637_477_s18_n1200_5Hz_low</variable_entry>
# 		</movie>
# 	</item>
# 	<loop_variable name="Position Loop Zscan">
# 		<file_path>positions_all.txt</file_path>
# 	</loop_variable>
# </recipe>

# %%
if not os.path.exists(source_folder):
    print(f"Create folder: {source_folder}")
    os.makedirs(source_folder)
    
save_filename = os.path.join(source_folder, f"generated_dave_H{hyb_start}-{hyb_start+num_rounds-1}.xml")
with open(save_filename, 'w') as _output_handle:
    print(f"Dave protocol saved to file: {save_filename}")
    _output_handle.write(final_str)
# Out:
# Dave protocol saved to file: E:\Data\20240515-4T1noMMt3v210xPE2_colony0501_IntBCv2new_Editv3\generated_dave_H17-25.xml
